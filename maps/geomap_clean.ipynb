# %%
import geopandas as gpd 

hualien_division_area = gpd.read_parquet("hualien_division_area.geoparquet")

mask = hualien_division_area.country == "TW"
mask &= ~hualien_division_area.subtype.isin("country")

hualien_division_area = hualien_division_area[mask]

hualien_division_area.explore()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 hualien_division_area = gpd.read_parquet("hualien_division_area.geoparquet")
#       5 mask = hualien_division_area.country == "TW"
# ----> 6 mask &= ~hualien_division_area.subtype.isin("country")
#       8 hualien_division_area = hualien_division_area[mask]
#      10 hualien_division_area.explore()
#
# File ~/personal_project/recall_vote_viz/.venv/lib/python3.11/site-packages/pandas/core/series.py:5570, in Series.isin(self, values)
#    5497 def isin(self, values) -> Series:
#    5498     """
#    5499     Whether elements in Series are contained in `values`.
#    5500
#    (...)   5568     dtype: bool
#    5569     """
# -> 5570     result = algorithms.isin(self._values, values)
#    5571     return self._constructor(result, index=self.index, copy=False).__finalize__(
# ...

# %%
import geopandas as gpd 

df = gpd.read_parquet('./hualien_division_area_village.geoparquet')

df.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
df
# Out:
#                                               geometry primary_name
# 31   POLYGON ((121.23326 23.16361, 121.23305 23.166...          學田村
# 33   POLYGON ((121.24076 23.17518, 121.23789 23.174...          富南村
# 34   POLYGON ((121.2523 23.18449, 121.25264 23.1849...          富里村
# 35   POLYGON ((121.2559 23.17926, 121.25395 23.1796...          永豐村
# 36   POLYGON ((121.25672 23.19274, 121.25914 23.195...          明里村
# ..                                                 ...          ...
# 292  POLYGON ((121.53972 24.13107, 121.53908 24.126...          秀林村
# 293  POLYGON ((121.64299 24.11963, 121.64068 24.122...          順安村
# 294  POLYGON ((121.58519 24.26015, 121.57808 24.257...          崇德村
# 305  POLYGON ((121.55613 24.25245, 121.56223 24.254...          和平村
# 308  POLYGON ((121.65455 24.12274, 121.65534 24.123...          新城村
#
# [188 rows x 2 columns]
